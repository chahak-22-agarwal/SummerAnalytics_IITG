# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
df=pd.read_csv("C:/Users/Lenovo/Desktop/Cars.csv")
print(df.columns)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
df.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
def get_column_name(df):
  return df.columns.tolist()

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
df=df.set_index('name')

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
mpg_value=[25,30,25,30,40]
unique_mpg_value=list(set(mpg_value))
print(unique_mpg_value)
# Out:
# [40, 25, 30]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
df['power_to_weight']=df['horsepower']/df['weight']
df=df.set_index('power_to_weight')

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
# Strip any whitespace from column names
df.columns = df.columns.str.strip()

# Drop rows with missing horsepower
df_clean = df.dropna(subset=["horsepower"])

# Find the maximum horsepower
max_hp = df_clean["horsepower"].max()

# Get car(s) with that horsepower
highest_hp_cars = df_clean[df_clean["horsepower"] == max_hp]

# Show car name and horsepower
print(highest_hp_cars[["name", "horsepower"]])
# Out:
#                    name  horsepower
# 116  pontiac grand prix       230.0

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
high_mpg_cars = df[df["mpg"] >= 35]


count = len(high_mpg_cars)
print(count)
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
filtered_cars = df[(df["horsepower"] > 100) & (df["weight"] < 3000)]

most_common_origin = filtered_cars["origin"].value_counts().idxmax()
print(most_common_origin)
# Out:
# usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
japanese_cars = df[df["origin"] == "japan"]

mean_acceleration = japanese_cars["acceleration"].mean()
print(mean_acceleration)
# Out:
# 16.17215189873418

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
avg_mpg_per_year = df.groupby("model_year")["mpg"].mean()


best_year = avg_mpg_per_year.idxmax()
highest_avg_mpg = avg_mpg_per_year.max()
print (avg_mpg_per_year)
print(best_year)
print(highest_avg_mpg)
# Out:
# model_year
# 70    17.689655
# 71    21.250000
# 72    18.714286
# 73    17.100000
# 74    22.703704
# 75    20.266667
# 76    21.573529
# 77    23.375000
# 78    24.061111
# 79    25.093103
# 80    33.696552
# 81    30.334483
# 82    31.709677
# Name: mpg, dtype: float64
# 80
# 33.69655172413793

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
# Calculate horsepower-to-weight ratio
above_median_mpg["hp_to_weight"] = above_median_mpg["horsepower"] / above_median_mpg["weight"]

# Find the maximum hp-to-weight ratio
max_ratio = above_median_mpg["hp_to_weight"].max()

# Get the car(s) with the best ratio
best_cars = above_median_mpg[above_median_mpg["hp_to_weight"] == max_ratio]


print(best_cars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Calculate horsepower-to-weight ratio
# ----> 2 above_median_mpg["hp_to_weight"] = above_median_mpg["horsepower"] / above_median_mpg["weight"]
#       4 # Find the maximum hp-to-weight ratio
#       5 max_ratio = above_median_mpg["hp_to_weight"].max()
#
# NameError: name 'above_median_mpg' is not defined

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here
import seaborn as sns
import matplotlib.pyplot as plt
avg_mpg_by_year_origin = df.groupby(["model_year", "origin"])["mpg"].mean().reset_index()


sns.set(style="whitegrid")

# Create the multi-line plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_mpg_by_year_origin, x="model_year", y="mpg", hue="origin", marker="o")

# Add labels and title
plt.title("Average MPG Over the Years by Origin")
plt.xlabel("Model Year")
plt.ylabel("Average MPG")
plt.legend(title="Origin")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
# Drop rows with missing horsepower values
df_clean = df.dropna(subset=["horsepower"])

# Set the hue order
hue_order = ['japan', 'europe', 'usa']

# Create the scatterplot
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df_clean,              # ✅ This line was missing
    x="horsepower",
    y="weight",
    hue="origin",
    size="mpg",
    sizes=(20, 200),
    hue_order=hue_order,
    palette="Set2",
    alpha=0.7
)

# Add titles and axis labels
plt.title("Horsepower vs Weight of Cars\n(Size indicates MPG, Color indicates Origin)", fontsize=14)
plt.xlabel("Horsepower", fontsize=12)
plt.ylabel("Weight", fontsize=12)
plt.legend(title="Origin", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
# Drop rows with missing mpg or model_year
df_clean = df.dropna(subset=["mpg", "model_year"])

# Step 1: Identify car names that appear in more than one model_year
car_year_counts = df_clean.groupby("name")["model_year"].nunique()
cars_multiple_years = car_year_counts[car_year_counts > 1].index

# Step 2: Filter data for those cars
multi_year_cars = df_clean[df_clean["name"].isin(cars_multiple_years)]

# Step 3: Compute std of mpg and count
grouped_stats = multi_year_cars.groupby("name").agg(
    appearances=("mpg", "count"),
    mpg_std=("mpg", "std"),
    avg_mpg=("mpg", "mean")
).reset_index()

# Step 4: Filter consistent cars (std < 1.0 and at least 2 appearances)
consistent_cars = grouped_stats[(grouped_stats["mpg_std"] < 1.0) & (grouped_stats["appearances"] >= 2)]

# Step 5: Sort by appearances (descending), then avg_mpg (descending)
consistent_sorted = consistent_cars.sort_values(by=["appearances", "avg_mpg"], ascending=[False, False])

# Display the result
print(consistent_sorted)
# Out:
#                          name  appearances   mpg_std    avg_mpg
# 26           ford galaxie 500            3  0.577350  14.333333
# 41          plymouth fury iii            3  0.577350  14.333333
# 49        toyota corolla 1200            2  0.707107  31.500000
# 35                  mazda 626            2  0.212132  31.450000
# 53          volkswagen rabbit            2  0.353553  29.250000
# 21               datsun pl510            2  0.000000  27.000000
# 45                  saab 99le            2  0.707107  24.500000
# 51             toyota mark ii            2  0.707107  19.500000
# 22                dodge aspen            2  0.353553  18.850000
# 10  chevrolet chevelle malibu            2  0.707107  17.500000
# 4            amc matador (sw)            2  0.707107  14.500000
# 28      ford gran torino (sw)            2  0.707107  13.500000
# 29                   ford ltd            2  0.707107  13.500000

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
